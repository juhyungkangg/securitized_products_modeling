# %%
import numpy as np
import pandas as pd
from modules.mortgage_calculator import *
import matplotlib.pyplot as plt
import locale
from IPython.display import display, HTML

mc = MortgageCalculator(100000, 0.04, 180)

# %%
mc.show()
# Out:
# **Input**
# Initla Principal: $100,000.00
# Annual Coupon: 4.00%
# Maturity (mths): 180
#
# **Output**
# Monthly Payment: $739.69
# WAL (yrs): 8.29
# <style type="text/css">
# </style>
# <table id="T_40963">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40963_level0_col0" class="col_heading level0 col0" >Month</th>
#       <th id="T_40963_level0_col1" class="col_heading level0 col1" >Begin Principal</th>
#       <th id="T_40963_level0_col2" class="col_heading level0 col2" >Mthly Pymt</th>
#       <th id="T_40963_level0_col3" class="col_heading level0 col3" >Interest Pymt</th>
#       <th id="T_40963_level0_col4" class="col_heading level0 col4" >Scheduled Principal Pymt</th>
#       <th id="T_40963_level0_col5" class="col_heading level0 col5" >End Principal</th>
#       <th id="T_40963_level0_col6" class="col_heading level0 col6" >Cumulative Interest Paid</th>
#       <th id="T_40963_level0_col7" class="col_heading level0 col7" >WAL (yrs)</th>
# ...

# %%
mc.plots()

# %%
import numpy as np

sa = ScenarioAnalyses(100000, 0.04, 180)

# %%
sa.WAL()
# Out:
# **Input**
# Initla Principal: $100,000.00
# Annual Coupon: 4.00%
# Maturity (mths): 180

# %%
sa.plot_2d_col_chart(coupon_rate_li=[0.04, 0.05, 0.06, 0.07, 0.08, 0.09],
                     maturity_li=[10*12, 15*12, 30*12])
